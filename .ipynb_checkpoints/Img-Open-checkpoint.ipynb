# %%
import nibabel as nib


# img1 = nib.load('img.nii')

img1 = nib.load('OneDrive_1_11-10-2021/AD_P522R_F5_153/MRI_50um/mag_sos_wn.nii')

# img2 = nib.load('other_file.nii.gz')
# img3 = nib.load('spm_file.img')

data = img1.get_fdata()
affine = img1.affine

print(img1)



# img2 = nib.load('imgSup.nii')

# img2 = nib.load('other_file.nii.gz')
# img3 = nib.load('spm_file.img')

# data2 = img2.get_fdata()
# affine2 = img2.affine

# print(img2)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (360, 256, 152)
# affine:
# [[0.05 0.   0.   0.05]
#  [0.   0.05 0.   0.05]
#  [0.   0.   0.05 0.05]
#  [0.   0.   0.   1.  ]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 360 256 152   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   0.05 0.05 0.05 1.   1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 54771
# glmin           : 560
# ...

# %%
from nilearn import plotting
plotting.plot_img(img1)
# plotting.plot_img(img2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/r0/vm3d6yq54b74bm6wwqrtxc9c0000gn/T/ipykernel_10296/2852261309.py in <module>
# ----> 1 from nilearn import plotting
#       2 plotting.plot_img(img1)
#       3 # plotting.plot_img(img2)
#
# ModuleNotFoundError: No module named 'nilearn'

# %%
from nilearn.plotting import plot_stat_map, plot_anat, plot_img
plot_img(img1)
plot_anat(img1)
plot_anat(img2)

# %%
import nibabel as nib

img1 = nib.load('25img.nii')

data = img1.get_fdata()
affine = img1.affine

print(img1)

img2 = nib.load('50img.nii')

data2 = img2.get_fdata()
affine2 = img2.affine

print(img2)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (720, 512, 304)
# affine:
# [[0.025 0.    0.    0.025]
#  [0.    0.025 0.    0.025]
#  [0.    0.    0.025 0.025]
#  [0.    0.    0.    1.   ]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 720 512 304   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.    0.025 0.025 0.025 1.    1.    1.    1.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 32845
# ...

# %%
from nilearn.plotting import plot_stat_map, plot_anat, plot_img
plot_img(img1)
plot_img(img2)
plot_anat(img1)
plot_anat(img2)
